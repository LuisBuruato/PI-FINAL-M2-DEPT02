# %%
# !pip install prefect
# Out:
# Collecting prefect
#   Downloading prefect-3.6.4-py3-none-any.whl.metadata (13 kB)
# Collecting aiosqlite<1.0.0,>=0.17.0 (from prefect)
#   Downloading aiosqlite-0.21.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting alembic<2.0.0,>=1.7.5 (from prefect)
#   Downloading alembic-1.17.2-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: anyio<5.0.0,>=4.4.0 in c:\users\luisb\anaconda3\lib\site-packages (from prefect) (4.7.0)
# Collecting apprise<2.0.0,>=1.1.0 (from prefect)
#   Downloading apprise-1.9.5-py3-none-any.whl.metadata (56 kB)
# Collecting asgi-lifespan<3.0,>=1.0 (from prefect)
#   Downloading asgi_lifespan-2.1.0-py3-none-any.whl.metadata (10 kB)
# Collecting asyncpg<1.0.0,>=0.23 (from prefect)
#   Downloading asyncpg-0.30.0-cp313-cp313-win_amd64.whl.metadata (5.2 kB)
# Requirement already satisfied: cachetools<7.0,>=5.3 in c:\users\luisb\anaconda3\lib\site-packages (from prefect) (5.5.1)
# Requirement already satisfied: click<9,>=8.0 in c:\users\luisb\anaconda3\lib\site-packages (from prefect) (8.1.8)
# Requirement already satisfied: cloudpickle<4.0,>=2.0 in c:\users\luisb\anaconda3\lib\site-packages (from prefect) (3.0.0)
# Collecting coolname<3.0.0,>=1.0.4 (from prefect)
#   Downloading coolname-2.2.0-py2.py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: cryptography>=36.0.1 in c:\users\luisb\anaconda3\lib\site-packages (from prefect) (44.0.1)
# Collecting dateparser<2.0.0,>=1.1.1 (from prefect)
#   Downloading dateparser-1.2.2-py3-none-any.whl.metadata (29 kB)
# Collecting docker<8.0,>=4.0 (from prefect)
#   Downloading docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting exceptiongroup>=1.0.0 (from prefect)
#   Downloading exceptiongroup-1.3.1-py3-none-any.whl.metadata (6.7 kB)
# Collecting fastapi<1.0.0,>=0.111.0 (from prefect)
#   Downloading fastapi-0.122.0-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: fsspec>=2022.5.0 in c:\users\luisb\anaconda3\lib\site-packages (from prefect) (2025.3.2)
# Requirement already satisfied: graphviz>=0.20.1 in c:\users\luisb\anaconda3\lib\site-packages (from prefect) (0.21)
# Collecting griffe<2.0.0,>=0.49.0 (from prefect)
#   Downloading griffe-1.15.0-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: httpcore<2.0.0,>=1.0.5 in c:\users\luisb\anaconda3\lib\site-packages (from prefect) (1.0.9)
# Requirement already satisfied: httpx!=0.23.2,>=0.23 in c:\users\luisb\anaconda3\lib\site-packages (from httpx[http2]!=0.23.2,>=0.23->prefect) (0.28.1)
# Collecting humanize<5.0.0,>=4.9.0 (from prefect)
#   Downloading humanize-4.14.0-py3-none-any.whl.metadata (7.8 kB)
# Collecting jinja2-humanize-extension>=0.4.0 (from prefect)
#   Downloading jinja2_humanize_extension-0.4.0-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.6 in c:\users\luisb\anaconda3\lib\site-packages (from prefect) (3.1.6)
# Requirement already satisfied: jsonpatch<2.0,>=1.32 in c:\users\luisb\anaconda3\lib\site-packages (from prefect) (1.33)
# Requirement already satisfied: jsonschema<5.0.0,>=4.18.0 in c:\users\luisb\anaconda3\lib\site-packages (from prefect) (4.23.0)
# Collecting opentelemetry-api<2.0.0,>=1.27.0 (from prefect)
#   Downloading opentelemetry_api-1.38.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: orjson<4.0,>=3.7 in c:\users\luisb\anaconda3\lib\site-packages (from prefect) (3.11.4)
# Requirement already satisfied: packaging<25.1,>=21.3 in c:\users\luisb\appdata\roaming\python\python313\site-packages (from prefect) (24.1)
# Requirement already satisfied: pathspec>=0.8.0 in c:\users\luisb\anaconda3\lib\site-packages (from prefect) (0.10.3)
# Collecting pluggy>=1.6.0 (from prefect)
#   Downloading pluggy-1.6.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: prometheus-client>=0.20.0 in c:\users\luisb\anaconda3\lib\site-packages (from prefect) (0.21.1)
# Requirement already satisfied: pydantic!=2.11.0,!=2.11.1,!=2.11.2,!=2.11.3,!=2.11.4,<3.0.0,>=2.10.1 in c:\users\luisb\anaconda3\lib\site-packages (from prefect) (2.10.3)
# Requirement already satisfied: pydantic-core<3.0.0,>=2.12.0 in c:\users\luisb\anaconda3\lib\site-packages (from prefect) (2.27.1)
# Collecting pydantic-extra-types<3.0.0,>=2.8.2 (from prefect)
#   Downloading pydantic_extra_types-2.10.6-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: pydantic-settings!=2.9.0,<3.0.0,>2.2.1 in c:\users\luisb\anaconda3\lib\site-packages (from prefect) (2.6.1)
# Collecting pydocket>=0.13.0 (from prefect)
#   Downloading pydocket-0.14.1-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.2 in c:\users\luisb\appdata\roaming\python\python313\site-packages (from prefect) (2.9.0.post0)
# Requirement already satisfied: python-slugify<9.0,>=5.0 in c:\users\luisb\anaconda3\lib\site-packages (from prefect) (5.0.2)
# Requirement already satisfied: pytz<2026,>=2021.1 in c:\users\luisb\anaconda3\lib\site-packages (from prefect) (2024.1)
# Requirement already satisfied: pyyaml<7.0.0,>=5.4.1 in c:\users\luisb\anaconda3\lib\site-packages (from prefect) (6.0.2)
# Requirement already satisfied: readchar<5.0.0,>=4.0.0 in c:\users\luisb\anaconda3\lib\site-packages (from prefect) (4.0.5)
# Requirement already satisfied: rfc3339-validator<0.2.0,>=0.1.4 in c:\users\luisb\anaconda3\lib\site-packages (from prefect) (0.1.4)
# Requirement already satisfied: rich<15.0,>=11.0 in c:\users\luisb\anaconda3\lib\site-packages (from prefect) (13.9.4)
# Requirement already satisfied: ruamel-yaml>=0.17.0 in c:\users\luisb\anaconda3\lib\site-packages (from prefect) (0.18.10)
# Collecting semver>=3.0.4 (from prefect)
#   Downloading semver-3.0.4-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: sniffio<2.0.0,>=1.3.0 in c:\users\luisb\anaconda3\lib\site-packages (from prefect) (1.3.0)
# Requirement already satisfied: sqlalchemy<3.0.0,>=2.0 in c:\users\luisb\anaconda3\lib\site-packages (from sqlalchemy[asyncio]<3.0.0,>=2.0->prefect) (2.0.39)
# Requirement already satisfied: toml>=0.10.0 in c:\users\luisb\anaconda3\lib\site-packages (from prefect) (0.10.2)
# Collecting typer<0.20.0,>=0.16.0 (from prefect)
#   Downloading typer-0.19.2-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.10.0 in c:\users\luisb\anaconda3\lib\site-packages (from prefect) (4.12.2)
# Collecting uv>=0.6.0 (from prefect)
#   Downloading uv-0.9.11-py3-none-win_amd64.whl.metadata (12 kB)
# Collecting uvicorn!=0.29.0,>=0.14.0 (from prefect)
#   Downloading uvicorn-0.38.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting websockets<16.0,>=15.0.1 (from prefect)
#   Downloading websockets-15.0.1-cp313-cp313-win_amd64.whl.metadata (7.0 kB)
# Collecting whenever<0.10.0,>=0.7.3 (from prefect)
#   Downloading whenever-0.9.3-cp313-cp313-win_amd64.whl.metadata (12 kB)
# Collecting Mako (from alembic<2.0.0,>=1.7.5->prefect)
#   Downloading mako-1.3.10-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: idna>=2.8 in c:\users\luisb\anaconda3\lib\site-packages (from anyio<5.0.0,>=4.4.0->prefect) (3.7)
# Requirement already satisfied: requests in c:\users\luisb\anaconda3\lib\site-packages (from apprise<2.0.0,>=1.1.0->prefect) (2.32.3)
# Collecting requests-oauthlib (from apprise<2.0.0,>=1.1.0->prefect)
#   Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: markdown in c:\users\luisb\anaconda3\lib\site-packages (from apprise<2.0.0,>=1.1.0->prefect) (3.8)
# Requirement already satisfied: certifi in c:\users\luisb\anaconda3\lib\site-packages (from apprise<2.0.0,>=1.1.0->prefect) (2025.7.14)
# Requirement already satisfied: tzdata in c:\users\luisb\anaconda3\lib\site-packages (from apprise<2.0.0,>=1.1.0->prefect) (2025.2)
# Requirement already satisfied: colorama in c:\users\luisb\appdata\roaming\python\python313\site-packages (from click<9,>=8.0->prefect) (0.4.6)
# Collecting pytz<2026,>=2021.1 (from prefect)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: regex>=2024.9.11 in c:\users\luisb\anaconda3\lib\site-packages (from dateparser<2.0.0,>=1.1.1->prefect) (2024.11.6)
# Collecting tzlocal>=0.2 (from dateparser<2.0.0,>=1.1.1->prefect)
#   Downloading tzlocal-5.3.1-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: pywin32>=304 in c:\users\luisb\appdata\roaming\python\python313\site-packages (from docker<8.0,>=4.0->prefect) (308)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\luisb\anaconda3\lib\site-packages (from docker<8.0,>=4.0->prefect) (2.3.0)
# Collecting starlette<0.51.0,>=0.40.0 (from fastapi<1.0.0,>=0.111.0->prefect)
#   Downloading starlette-0.50.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting annotated-doc>=0.0.2 (from fastapi<1.0.0,>=0.111.0->prefect)
#   Downloading annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: h11>=0.16 in c:\users\luisb\anaconda3\lib\site-packages (from httpcore<2.0.0,>=1.0.5->prefect) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\luisb\anaconda3\lib\site-packages (from jinja2<4.0.0,>=3.1.6->prefect) (3.0.2)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\luisb\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.32->prefect) (2.1)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\luisb\anaconda3\lib\site-packages (from jsonschema<5.0.0,>=4.18.0->prefect) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\luisb\anaconda3\lib\site-packages (from jsonschema<5.0.0,>=4.18.0->prefect) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\luisb\anaconda3\lib\site-packages (from jsonschema<5.0.0,>=4.18.0->prefect) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\luisb\anaconda3\lib\site-packages (from jsonschema<5.0.0,>=4.18.0->prefect) (0.22.3)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\luisb\anaconda3\lib\site-packages (from opentelemetry-api<2.0.0,>=1.27.0->prefect) (8.5.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\luisb\anaconda3\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api<2.0.0,>=1.27.0->prefect) (3.21.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\luisb\anaconda3\lib\site-packages (from pydantic!=2.11.0,!=2.11.1,!=2.11.2,!=2.11.3,!=2.11.4,<3.0.0,>=2.10.1->prefect) (0.6.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\luisb\anaconda3\lib\site-packages (from pydantic-settings!=2.9.0,<3.0.0,>2.2.1->prefect) (1.1.0)
# Requirement already satisfied: six>=1.5 in c:\users\luisb\appdata\roaming\python\python313\site-packages (from python-dateutil<3.0.0,>=2.8.2->prefect) (1.16.0)
# Requirement already satisfied: text-unidecode>=1.3 in c:\users\luisb\anaconda3\lib\site-packages (from python-slugify<9.0,>=5.0->prefect) (1.3)
# Requirement already satisfied: setuptools>=41.0 in c:\users\luisb\anaconda3\lib\site-packages (from readchar<5.0.0,>=4.0.0->prefect) (72.1.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\luisb\anaconda3\lib\site-packages (from rich<15.0,>=11.0->prefect) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\luisb\appdata\roaming\python\python313\site-packages (from rich<15.0,>=11.0->prefect) (2.18.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\luisb\anaconda3\lib\site-packages (from sqlalchemy<3.0.0,>=2.0->sqlalchemy[asyncio]<3.0.0,>=2.0->prefect) (3.1.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\luisb\anaconda3\lib\site-packages (from typer<0.20.0,>=0.16.0->prefect) (1.5.0)
# Requirement already satisfied: cffi>=1.12 in c:\users\luisb\anaconda3\lib\site-packages (from cryptography>=36.0.1->prefect) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\luisb\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=36.0.1->prefect) (2.21)
# Collecting h2<5,>=3 (from httpx[http2]!=0.23.2,>=0.23->prefect)
#   Downloading h2-4.3.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting hyperframe<7,>=6.1 (from h2<5,>=3->httpx[http2]!=0.23.2,>=0.23->prefect)
#   Downloading hyperframe-6.1.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting hpack<5,>=4.1 (from h2<5,>=3->httpx[http2]!=0.23.2,>=0.23->prefect)
#   Downloading hpack-4.1.0-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: mdurl~=0.1 in c:\users\luisb\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich<15.0,>=11.0->prefect) (0.1.0)
# Collecting cloudpickle<4.0,>=2.0 (from prefect)
#   Downloading cloudpickle-3.1.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting fakeredis>=2.32.1 (from fakeredis[lua]>=2.32.1->pydocket>=0.13.0->prefect)
#   Downloading fakeredis-2.32.1-py3-none-any.whl.metadata (4.5 kB)
# Collecting opentelemetry-exporter-prometheus>=0.51b0 (from pydocket>=0.13.0->prefect)
#   Downloading opentelemetry_exporter_prometheus-0.59b0-py3-none-any.whl.metadata (2.1 kB)
# Collecting py-key-value-aio>=0.3.0 (from py-key-value-aio[memory,redis]>=0.3.0->pydocket>=0.13.0->prefect)
#   Downloading py_key_value_aio-0.3.0-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: python-json-logger>=2.0.7 in c:\users\luisb\anaconda3\lib\site-packages (from pydocket>=0.13.0->prefect) (3.2.1)
# Collecting redis>=5 (from pydocket>=0.13.0->prefect)
#   Downloading redis-7.1.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: sortedcontainers>=2 in c:\users\luisb\anaconda3\lib\site-packages (from fakeredis>=2.32.1->fakeredis[lua]>=2.32.1->pydocket>=0.13.0->prefect) (2.4.0)
# Collecting lupa>=2.1 (from fakeredis[lua]>=2.32.1->pydocket>=0.13.0->prefect)
#   Downloading lupa-2.6-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Collecting opentelemetry-sdk~=1.38.0 (from opentelemetry-exporter-prometheus>=0.51b0->pydocket>=0.13.0->prefect)
#   Downloading opentelemetry_sdk-1.38.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-semantic-conventions==0.59b0 (from opentelemetry-sdk~=1.38.0->opentelemetry-exporter-prometheus>=0.51b0->pydocket>=0.13.0->prefect)
#   Downloading opentelemetry_semantic_conventions-0.59b0-py3-none-any.whl.metadata (2.4 kB)
# Collecting py-key-value-shared==0.3.0 (from py-key-value-aio>=0.3.0->py-key-value-aio[memory,redis]>=0.3.0->pydocket>=0.13.0->prefect)
#   Downloading py_key_value_shared-0.3.0-py3-none-any.whl.metadata (706 bytes)
# Collecting beartype>=0.20.0 (from py-key-value-aio>=0.3.0->py-key-value-aio[memory,redis]>=0.3.0->pydocket>=0.13.0->prefect)
#   Downloading beartype-0.22.6-py3-none-any.whl.metadata (36 kB)
# Collecting typing-extensions<5.0.0,>=4.10.0 (from prefect)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\luisb\anaconda3\lib\site-packages (from requests->apprise<2.0.0,>=1.1.0->prefect) (3.3.2)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib->apprise<2.0.0,>=1.1.0->prefect)
#   Downloading oauthlib-3.3.1-py3-none-any.whl.metadata (7.9 kB)
# Downloading prefect-3.6.4-py3-none-any.whl (6.2 MB)
#    ---------------------------------------- 0.0/6.2 MB ? eta -:--:--
#    ---------------------- ----------------- 3.4/6.2 MB 20.2 MB/s eta 0:00:01
#    ---------------------------------------- 6.2/6.2 MB 28.4 MB/s eta 0:00:00
# Downloading aiosqlite-0.21.0-py3-none-any.whl (15 kB)
# Downloading alembic-1.17.2-py3-none-any.whl (248 kB)
# Downloading apprise-1.9.5-py3-none-any.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 1.4/1.4 MB 80.7 MB/s eta 0:00:00
# Downloading asgi_lifespan-2.1.0-py3-none-any.whl (10 kB)
# Downloading asyncpg-0.30.0-cp313-cp313-win_amd64.whl (621 kB)
#    ---------------------------------------- 0.0/621.6 kB ? eta -:--:--
#    --------------------------------------- 621.6/621.6 kB 22.3 MB/s eta 0:00:00
# Downloading coolname-2.2.0-py2.py3-none-any.whl (37 kB)
# Downloading dateparser-1.2.2-py3-none-any.whl (315 kB)
# Downloading docker-7.1.0-py3-none-any.whl (147 kB)
# Downloading fastapi-0.122.0-py3-none-any.whl (110 kB)
# Downloading griffe-1.15.0-py3-none-any.whl (150 kB)
# Downloading humanize-4.14.0-py3-none-any.whl (132 kB)
# Downloading opentelemetry_api-1.38.0-py3-none-any.whl (65 kB)
# Downloading pydantic_extra_types-2.10.6-py3-none-any.whl (40 kB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading starlette-0.50.0-py3-none-any.whl (74 kB)
# Downloading typer-0.19.2-py3-none-any.whl (46 kB)
# Downloading websockets-15.0.1-cp313-cp313-win_amd64.whl (176 kB)
# Downloading whenever-0.9.3-cp313-cp313-win_amd64.whl (422 kB)
# Downloading annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Downloading exceptiongroup-1.3.1-py3-none-any.whl (16 kB)
# Downloading h2-4.3.0-py3-none-any.whl (61 kB)
# Downloading hpack-4.1.0-py3-none-any.whl (34 kB)
# Downloading hyperframe-6.1.0-py3-none-any.whl (13 kB)
# Downloading jinja2_humanize_extension-0.4.0-py3-none-any.whl (4.8 kB)
# Downloading pluggy-1.6.0-py3-none-any.whl (20 kB)
# Downloading pydocket-0.14.1-py3-none-any.whl (57 kB)
# Downloading cloudpickle-3.1.2-py3-none-any.whl (22 kB)
# Downloading fakeredis-2.32.1-py3-none-any.whl (118 kB)
# Downloading lupa-2.6-cp313-cp313-win_amd64.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 1.7/1.7 MB 30.8 MB/s eta 0:00:00
# Downloading opentelemetry_exporter_prometheus-0.59b0-py3-none-any.whl (13 kB)
# Downloading opentelemetry_sdk-1.38.0-py3-none-any.whl (132 kB)
# Downloading opentelemetry_semantic_conventions-0.59b0-py3-none-any.whl (207 kB)
# Downloading py_key_value_aio-0.3.0-py3-none-any.whl (96 kB)
# Downloading py_key_value_shared-0.3.0-py3-none-any.whl (19 kB)
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading beartype-0.22.6-py3-none-any.whl (1.3 MB)
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    ---------------------------------------- 1.3/1.3 MB 16.2 MB/s eta 0:00:00
# Downloading redis-7.1.0-py3-none-any.whl (354 kB)
# Downloading semver-3.0.4-py3-none-any.whl (17 kB)
# Downloading tzlocal-5.3.1-py3-none-any.whl (18 kB)
# Downloading uv-0.9.11-py3-none-win_amd64.whl (21.6 MB)
#    ---------------------------------------- 0.0/21.6 MB ? eta -:--:--
#    ---------------- ----------------------- 8.7/21.6 MB 42.8 MB/s eta 0:00:01
#    ------------------------ --------------- 13.1/21.6 MB 30.7 MB/s eta 0:00:01
#    ---------------------------------------- 21.6/21.6 MB 35.1 MB/s eta 0:00:00
# Downloading uvicorn-0.38.0-py3-none-any.whl (68 kB)
# Downloading mako-1.3.10-py3-none-any.whl (78 kB)
# Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Downloading oauthlib-3.3.1-py3-none-any.whl (160 kB)
# Installing collected packages: pytz, lupa, coolname, websockets, uv, tzlocal, typing-extensions, semver, redis, pluggy, oauthlib, Mako, hyperframe, humanize, hpack, griffe, exceptiongroup, cloudpickle, beartype, asyncpg, asgi-lifespan, annotated-doc, whenever, uvicorn, starlette, requests-oauthlib, py-key-value-shared, opentelemetry-api, jinja2-humanize-extension, h2, fakeredis, docker, dateparser, aiosqlite, typer, py-key-value-aio, opentelemetry-semantic-conventions, apprise, alembic, pydantic-extra-types, opentelemetry-sdk, fastapi, opentelemetry-exporter-prometheus, pydocket, prefect
#
#   Attempting uninstall: pytz
#
#     Found existing installation: pytz 2024.1
#
#    ----------------------------------------  0/45 [pytz]
#     Uninstalling pytz-2024.1:
#    ----------------------------------------  0/45 [pytz]
#       Successfully uninstalled pytz-2024.1
#    ----------------------------------------  0/45 [pytz]
#    ----------------------------------------  0/45 [pytz]
#    ----------------------------------------  0/45 [pytz]
#    ----------------------------------------  0/45 [pytz]
#    - --------------------------------------  2/45 [coolname]
#    -- -------------------------------------  3/45 [websockets]
#    --- ------------------------------------  4/45 [uv]
#    --- ------------------------------------  4/45 [uv]
#   Attempting uninstall: typing-extensions
#    --- ------------------------------------  4/45 [uv]
#     Found existing installation: typing_extensions 4.12.2
#    --- ------------------------------------  4/45 [uv]
#    ----- ----------------------------------  6/45 [typing-extensions]
#     Uninstalling typing_extensions-4.12.2:
#    ----- ----------------------------------  6/45 [typing-extensions]
#    ----- ----------------------------------  6/45 [typing-extensions]
#    ----- ----------------------------------  6/45 [typing-extensions]
#    ----- ----------------------------------  6/45 [typing-extensions]
#    ----- ----------------------------------  6/45 [typing-extensions]
#    ----- ----------------------------------  6/45 [typing-extensions]
#    ----- ----------------------------------  6/45 [typing-extensions]
#    ----- ----------------------------------  6/45 [typing-extensions]
#    ----- ----------------------------------  6/45 [typing-extensions]
#    ----- ----------------------------------  6/45 [typing-extensions]
#    ----- ----------------------------------  6/45 [typing-extensions]
#       Successfully uninstalled typing_extensions-4.12.2
#    ----- ----------------------------------  6/45 [typing-extensions]
#    ----- ----------------------------------  6/45 [typing-extensions]
#    ----- ----------------------------------  6/45 [typing-extensions]
#    ----- ----------------------------------  6/45 [typing-extensions]
#    ----- ----------------------------------  6/45 [typing-extensions]
#    ----- ----------------------------------  6/45 [typing-extensions]
#    ----- ----------------------------------  6/45 [typing-extensions]
#    ----- ----------------------------------  6/45 [typing-extensions]
#    ----- ----------------------------------  6/45 [typing-extensions]
#    ----- ----------------------------------  6/45 [typing-extensions]
#    ----- ----------------------------------  6/45 [typing-extensions]
#   Attempting uninstall: semver
#    ----- ----------------------------------  6/45 [typing-extensions]
#     Found existing installation: semver 3.0.2
#    ----- ----------------------------------  6/45 [typing-extensions]
#     Uninstalling semver-3.0.2:
#    ----- ----------------------------------  6/45 [typing-extensions]
#       Successfully uninstalled semver-3.0.2
#    ----- ----------------------------------  6/45 [typing-extensions]
#    ------ ---------------------------------  7/45 [semver]
#    ------- --------------------------------  8/45 [redis]
#    ------- --------------------------------  8/45 [redis]
#    ------- --------------------------------  8/45 [redis]
#   Attempting uninstall: pluggy
#    ------- --------------------------------  8/45 [redis]
#     Found existing installation: pluggy 1.5.0
#    ------- --------------------------------  8/45 [redis]
#     Uninstalling pluggy-1.5.0:
#    ------- --------------------------------  8/45 [redis]
#       Successfully uninstalled pluggy-1.5.0
#    ------- --------------------------------  8/45 [redis]
#    -------- -------------------------------  9/45 [pluggy]
#    -------- ------------------------------- 10/45 [oauthlib]
#    --------- ------------------------------ 11/45 [Mako]
#    ---------- ----------------------------- 12/45 [hyperframe]
#    ------------ --------------------------- 14/45 [hpack]
#    ------------- -------------------------- 15/45 [griffe]
#    -------------- ------------------------- 16/45 [exceptiongroup]
#   Attempting uninstall: cloudpickle
#    -------------- ------------------------- 16/45 [exceptiongroup]
#     Found existing installation: cloudpickle 3.0.0
#    -------------- ------------------------- 16/45 [exceptiongroup]
#     Uninstalling cloudpickle-3.0.0:
#    -------------- ------------------------- 16/45 [exceptiongroup]
#       Successfully uninstalled cloudpickle-3.0.0
#    -------------- ------------------------- 16/45 [exceptiongroup]
#    ---------------- ----------------------- 18/45 [beartype]
#    ---------------- ----------------------- 18/45 [beartype]
#    ---------------- ----------------------- 18/45 [beartype]
#    ---------------- ----------------------- 18/45 [beartype]
#    ---------------- ----------------------- 18/45 [beartype]
#    ---------------- ----------------------- 18/45 [beartype]
#    ---------------- ----------------------- 18/45 [beartype]
#    ---------------- ----------------------- 18/45 [beartype]
#    ---------------- ----------------------- 18/45 [beartype]
#    ---------------- ----------------------- 19/45 [asyncpg]
#    ----------------- ---------------------- 20/45 [asgi-lifespan]
#    ------------------- -------------------- 22/45 [whenever]
#    -------------------- ------------------- 23/45 [uvicorn]
#    --------------------- ------------------ 24/45 [starlette]
#    ---------------------- ----------------- 25/45 [requests-oauthlib]
#    ------------------------ --------------- 27/45 [opentelemetry-api]
#    ------------------------- -------------- 29/45 [h2]
#    -------------------------- ------------- 30/45 [fakeredis]
#    -------------------------- ------------- 30/45 [fakeredis]
#    --------------------------- ------------ 31/45 [docker]
#    ---------------------------- ----------- 32/45 [dateparser]
#    ---------------------------- ----------- 32/45 [dateparser]
#    ---------------------------- ----------- 32/45 [dateparser]
#    ---------------------------- ----------- 32/45 [dateparser]
#    ---------------------------- ----------- 32/45 [dateparser]
#    ---------------------------- ----------- 32/45 [dateparser]
#    ---------------------------- ----------- 32/45 [dateparser]
#    ----------------------------- ---------- 33/45 [aiosqlite]
#   Attempting uninstall: typer
#    ----------------------------- ---------- 33/45 [aiosqlite]
#     Found existing installation: typer 0.9.0
#    ----------------------------- ---------- 33/45 [aiosqlite]
#     Uninstalling typer-0.9.0:
#    ----------------------------- ---------- 33/45 [aiosqlite]
#       Successfully uninstalled typer-0.9.0
#    ----------------------------- ---------- 33/45 [aiosqlite]
#    ------------------------------ --------- 34/45 [typer]
#    ------------------------------- -------- 35/45 [py-key-value-aio]
#    ------------------------------- -------- 35/45 [py-key-value-aio]
#    -------------------------- ------ 36/45 [opentelemetry-semantic-conventions]
#    -------------------------- ------ 36/45 [opentelemetry-semantic-conventions]
#    -------------------------- ------ 36/45 [opentelemetry-semantic-conventions]
#    -------------------------- ------ 36/45 [opentelemetry-semantic-conventions]
#    -------------------------------- ------- 37/45 [apprise]
#    -------------------------------- ------- 37/45 [apprise]
#    -------------------------------- ------- 37/45 [apprise]
#    -------------------------------- ------- 37/45 [apprise]
#    -------------------------------- ------- 37/45 [apprise]
#    -------------------------------- ------- 37/45 [apprise]
#    -------------------------------- ------- 37/45 [apprise]
#    --------------------------------- ------ 38/45 [alembic]
#    --------------------------------- ------ 38/45 [alembic]
#    --------------------------------- ------ 38/45 [alembic]
#    ----------------------------------- ---- 40/45 [opentelemetry-sdk]
#    ----------------------------------- ---- 40/45 [opentelemetry-sdk]
#    ------------------------------------ --- 41/45 [fastapi]
#    ------------------------------------ --- 41/45 [fastapi]
#    -------------------------------------- - 43/45 [pydocket]
#    ---------------------------------------  44/45 [prefect]
#    ---------------------------------------  44/45 [prefect]
#    ---------------------------------------  44/45 [prefect]
#    ---------------------------------------  44/45 [prefect]
#    ---------------------------------------  44/45 [prefect]
#    ---------------------------------------  44/45 [prefect]
#    ---------------------------------------  44/45 [prefect]
#    ---------------------------------------  44/45 [prefect]
#    ---------------------------------------  44/45 [prefect]
#    ---------------------------------------  44/45 [prefect]
#    ---------------------------------------  44/45 [prefect]
#    ---------------------------------------  44/45 [prefect]
#    ---------------------------------------  44/45 [prefect]
#    ---------------------------------------  44/45 [prefect]
#    ---------------------------------------  44/45 [prefect]
#    ---------------------------------------  44/45 [prefect]
#    ---------------------------------------  44/45 [prefect]
#    ---------------------------------------  44/45 [prefect]
#    ---------------------------------------  44/45 [prefect]
#    ---------------------------------------  44/45 [prefect]
#    ---------------------------------------  44/45 [prefect]
#    ---------------------------------------  44/45 [prefect]
#    ---------------------------------------  44/45 [prefect]
#    ---------------------------------------  44/45 [prefect]
#    ---------------------------------------  44/45 [prefect]
#    ---------------------------------------- 45/45 [prefect]
#
# Successfully installed Mako-1.3.10 aiosqlite-0.21.0 alembic-1.17.2 annotated-doc-0.0.4 apprise-1.9.5 asgi-lifespan-2.1.0 asyncpg-0.30.0 beartype-0.22.6 cloudpickle-3.1.2 coolname-2.2.0 dateparser-1.2.2 docker-7.1.0 exceptiongroup-1.3.1 fakeredis-2.32.1 fastapi-0.122.0 griffe-1.15.0 h2-4.3.0 hpack-4.1.0 humanize-4.14.0 hyperframe-6.1.0 jinja2-humanize-extension-0.4.0 lupa-2.6 oauthlib-3.3.1 opentelemetry-api-1.38.0 opentelemetry-exporter-prometheus-0.59b0 opentelemetry-sdk-1.38.0 opentelemetry-semantic-conventions-0.59b0 pluggy-1.6.0 prefect-3.6.4 py-key-value-aio-0.3.0 py-key-value-shared-0.3.0 pydantic-extra-types-2.10.6 pydocket-0.14.1 pytz-2025.2 redis-7.1.0 requests-oauthlib-2.0.0 semver-3.0.4 starlette-0.50.0 typer-0.19.2 typing-extensions-4.15.0 tzlocal-5.3.1 uv-0.9.11 uvicorn-0.38.0 websockets-15.0.1 whenever-0.9.3

# %%
# !prefect version
# Out:
# Version:              3.6.4
# API version:          0.8.4
# Python version:       3.13.5
# Git commit:           d3c3ed50
# Built:                Fri, Nov 21, 2025 06:04 PM
# OS/Arch:              win32/AMD64
# Profile:              ephemeral
# Server type:          ephemeral
# Pydantic version:     2.10.3
# Server:
#   Database:           sqlite
#   SQLite version:     3.45.3

# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\luisb\\Desktop\\3.DEM2L7TRANSFORM_DBT\\notebooks'

# %%
# !python prefect_flow.py
# Out:
# 16:30:16.268 | INFO    | prefect - Starting temporary server on http://127.0.0.1:8203
# See https://docs.prefect.io/v3/concepts/server#how-to-guides for more information on running a dedicated Prefect server.
# 16:30:33.583 | INFO    | Flow run 'petite-saluki' - Beginning flow run 'petite-saluki' for flow 'ETL_Ecommerce'
# 16:30:33.996 | ERROR   | Task run 'task_extract-91f' - Error encountered when computing cache key - result will not be persisted.
# Traceback (most recent call last):
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\cache_policies.py", line 374, in compute_key
#     return hash_objects(hashed_inputs, raise_on_failure=True)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\utilities\hashing.py", line 89, in hash_objects
#     raise HashError(msg)
# prefect.exceptions.HashError: Unable to create hash - objects could not be serialized.
#   JSON error: Unable to serialize unknown type: <class 'sqlalchemy.engine.base.Engine'>
#   Pickle error: cannot pickle '_thread.RLock' object
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\task_engine.py", line 171, in compute_transaction_key
#     key = self.task.cache_policy.compute_key(
#         task_ctx=task_run_context,
#         inputs=self.parameters or {},
#         flow_parameters=parameters or {},
#     )
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\cache_policies.py", line 214, in compute_key
#     policy_key = policy.compute_key(
#         task_ctx=task_ctx,
#     ...<2 lines>...
#         **kwargs,
#     )
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\cache_policies.py", line 384, in compute_key
#     raise ValueError(msg) from exc
# ValueError: Unable to create hash - objects could not be serialized.
#   JSON error: Unable to serialize unknown type: <class 'sqlalchemy.engine.base.Engine'>
#   Pickle error: cannot pickle '_thread.RLock' object
#
# This often occurs when task inputs contain objects that cannot be cached like locks, file handles, or other system resources.
#
# To resolve this, you can:
#   1. Exclude these arguments by defining a custom `cache_key_fn`
#   2. Disable caching by passing `cache_policy=NO_CACHE`
#
# 16:30:34.012 | ERROR   | Task run 'task_extract-91f' - Task run failed with exception: InterfaceError("(pyodbc.InterfaceError) ('IM002', '[IM002] [Microsoft][ODBC Driver Manager] Data source name not found and no default driver specified (0) (SQLDriverConnect); [IM002] [Microsoft][ODBC Driver Manager] Invalid connection string attribute (0)')")
# Traceback (most recent call last):
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py", line 146, in __init__
#     self._dbapi_connection = engine.raw_connection()
#                              ~~~~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py", line 3298, in raw_connection
#     return self.pool.connect()
#            ~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 449, in connect
#     return _ConnectionFairy._checkout(self)
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 1264, in _checkout
#     fairy = _ConnectionRecord.checkout(pool)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 713, in checkout
#     rec = pool._do_get()
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\impl.py", line 179, in _do_get
#     with util.safe_reraise():
#          ~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\util\langhelpers.py", line 146, in __exit__
#     raise exc_value.with_traceback(exc_tb)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\impl.py", line 177, in _do_get
#     return self._create_connection()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 390, in _create_connection
#     return _ConnectionRecord(self)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 675, in __init__
#     self.__connect()
#     ~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 901, in __connect
#     with util.safe_reraise():
#          ~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\util\langhelpers.py", line 146, in __exit__
#     raise exc_value.with_traceback(exc_tb)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 897, in __connect
#     self.dbapi_connection = connection = pool._invoke_creator(self)
#                                          ~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\create.py", line 646, in connect
#     return dialect.connect(*cargs, **cparams)
#            ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\default.py", line 622, in connect
#     return self.loaded_dbapi.connect(*cargs, **cparams)
#            ~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^
# pyodbc.InterfaceError: ('IM002', '[IM002] [Microsoft][ODBC Driver Manager] Data source name not found and no default driver specified (0) (SQLDriverConnect); [IM002] [Microsoft][ODBC Driver Manager] Invalid connection string attribute (0)')
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\task_engine.py", line 884, in run_context
#     yield self
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\task_engine.py", line 1538, in run_task_sync
#     engine.call_task_fn(txn)
#     ~~~~~~~~~~~~~~~~~~~^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\task_engine.py", line 901, in call_task_fn
#     result = call_with_parameters(self.task.fn, parameters)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\utilities\callables.py", line 210, in call_with_parameters
#     return fn(*args, **kwargs)
#   File "c:\Users\luisb\Desktop\3.DEM2L7TRANSFORM_DBT\notebooks\prefect_flow.py", line 14, in task_extract
#     return extract_data(engine)
#   File "c:\Users\luisb\Desktop\3.DEM2L7TRANSFORM_DBT\notebooks\extract.py", line 19, in extract_data
#     "usuarios": extract_usuarios(engine),
#                 ~~~~~~~~~~~~~~~~^^^^^^^^
#   File "c:\Users\luisb\Desktop\3.DEM2L7TRANSFORM_DBT\notebooks\extract.py", line 7, in extract_usuarios
#     return pd.read_sql(query, engine)
#            ~~~~~~~~~~~^^^^^^^^^^^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\pandas\io\sql.py", line 704, in read_sql
#     with pandasSQL_builder(con) as pandas_sql:
#          ~~~~~~~~~~~~~~~~~^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\pandas\io\sql.py", line 906, in pandasSQL_builder
#     return SQLDatabase(con, schema, need_transaction)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\pandas\io\sql.py", line 1636, in __init__
#     con = self.exit_stack.enter_context(con.connect())
#                                         ~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py", line 3274, in connect
#     return self._connection_cls(self)
#            ~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py", line 148, in __init__
#     Connection._handle_dbapi_exception_noconnection(
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         err, dialect, engine
#         ^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py", line 2439, in _handle_dbapi_exception_noconnection
#     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py", line 146, in __init__
#     self._dbapi_connection = engine.raw_connection()
#                              ~~~~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py", line 3298, in raw_connection
#     return self.pool.connect()
#            ~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 449, in connect
#     return _ConnectionFairy._checkout(self)
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 1264, in _checkout
#     fairy = _ConnectionRecord.checkout(pool)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 713, in checkout
#     rec = pool._do_get()
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\impl.py", line 179, in _do_get
#     with util.safe_reraise():
#          ~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\util\langhelpers.py", line 146, in __exit__
#     raise exc_value.with_traceback(exc_tb)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\impl.py", line 177, in _do_get
#     return self._create_connection()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 390, in _create_connection
#     return _ConnectionRecord(self)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 675, in __init__
#     self.__connect()
#     ~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 901, in __connect
#     with util.safe_reraise():
#          ~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\util\langhelpers.py", line 146, in __exit__
#     raise exc_value.with_traceback(exc_tb)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 897, in __connect
#     self.dbapi_connection = connection = pool._invoke_creator(self)
#                                          ~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\create.py", line 646, in connect
#     return dialect.connect(*cargs, **cparams)
#            ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\default.py", line 622, in connect
#     return self.loaded_dbapi.connect(*cargs, **cparams)
#            ~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^
# sqlalchemy.exc.InterfaceError: (pyodbc.InterfaceError) ('IM002', '[IM002] [Microsoft][ODBC Driver Manager] Data source name not found and no default driver specified (0) (SQLDriverConnect); [IM002] [Microsoft][ODBC Driver Manager] Invalid connection string attribute (0)')
# (Background on this error at: https://sqlalche.me/e/20/rvf5)
# 16:30:34.036 | ERROR   | Task run 'task_extract-91f' - Finished in state Failed("Task run encountered an exception InterfaceError: (pyodbc.InterfaceError) ('IM002', '[IM002] [Microsoft][ODBC Driver Manager] Data source name not found and no default driver specified (0) (SQLDriverConnect); [IM002] [Microsoft][ODBC Driver Manager] Invalid connection string attribute (0)')\n(Background on this error at: https://sqlalche.me/e/20/rvf5)")
# 16:30:34.037 | ERROR   | Flow run 'petite-saluki' - Encountered exception during execution: InterfaceError("(pyodbc.InterfaceError) ('IM002', '[IM002] [Microsoft][ODBC Driver Manager] Data source name not found and no default driver specified (0) (SQLDriverConnect); [IM002] [Microsoft][ODBC Driver Manager] Invalid connection string attribute (0)')")
# Traceback (most recent call last):
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py", line 146, in __init__
#     self._dbapi_connection = engine.raw_connection()
#                              ~~~~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py", line 3298, in raw_connection
#     return self.pool.connect()
#            ~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 449, in connect
#     return _ConnectionFairy._checkout(self)
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 1264, in _checkout
#     fairy = _ConnectionRecord.checkout(pool)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 713, in checkout
#     rec = pool._do_get()
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\impl.py", line 179, in _do_get
#     with util.safe_reraise():
#          ~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\util\langhelpers.py", line 146, in __exit__
#     raise exc_value.with_traceback(exc_tb)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\impl.py", line 177, in _do_get
#     return self._create_connection()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 390, in _create_connection
#     return _ConnectionRecord(self)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 675, in __init__
#     self.__connect()
#     ~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 901, in __connect
#     with util.safe_reraise():
#          ~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\util\langhelpers.py", line 146, in __exit__
#     raise exc_value.with_traceback(exc_tb)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 897, in __connect
#     self.dbapi_connection = connection = pool._invoke_creator(self)
#                                          ~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\create.py", line 646, in connect
#     return dialect.connect(*cargs, **cparams)
#            ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\default.py", line 622, in connect
#     return self.loaded_dbapi.connect(*cargs, **cparams)
#            ~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^
# pyodbc.InterfaceError: ('IM002', '[IM002] [Microsoft][ODBC Driver Manager] Data source name not found and no default driver specified (0) (SQLDriverConnect); [IM002] [Microsoft][ODBC Driver Manager] Invalid connection string attribute (0)')
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\flow_engine.py", line 797, in run_context
#     yield self
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\flow_engine.py", line 1425, in run_flow_sync
#     engine.call_flow_fn()
#     ~~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\flow_engine.py", line 817, in call_flow_fn
#     result = call_with_parameters(self.flow.fn, self.parameters)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\utilities\callables.py", line 210, in call_with_parameters
#     return fn(*args, **kwargs)
#   File "c:\Users\luisb\Desktop\3.DEM2L7TRANSFORM_DBT\notebooks\prefect_flow.py", line 28, in ecommerce_flow
#     raw = task_extract(engine)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\tasks.py", line 1190, in __call__
#     return run_task(
#         task=self,
#     ...<2 lines>...
#         return_type=return_type,
#     )
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\task_engine.py", line 1765, in run_task
#     return run_task_sync(**kwargs)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\task_engine.py", line 1540, in run_task_sync
#     return engine.state if return_type == "state" else engine.result()
#                                                        ~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\task_engine.py", line 499, in result
#     raise self._raised
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\task_engine.py", line 884, in run_context
#     yield self
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\task_engine.py", line 1538, in run_task_sync
#     engine.call_task_fn(txn)
#     ~~~~~~~~~~~~~~~~~~~^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\task_engine.py", line 901, in call_task_fn
#     result = call_with_parameters(self.task.fn, parameters)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\utilities\callables.py", line 210, in call_with_parameters
#     return fn(*args, **kwargs)
#   File "c:\Users\luisb\Desktop\3.DEM2L7TRANSFORM_DBT\notebooks\prefect_flow.py", line 14, in task_extract
#     return extract_data(engine)
#   File "c:\Users\luisb\Desktop\3.DEM2L7TRANSFORM_DBT\notebooks\extract.py", line 19, in extract_data
#     "usuarios": extract_usuarios(engine),
#                 ~~~~~~~~~~~~~~~~^^^^^^^^
#   File "c:\Users\luisb\Desktop\3.DEM2L7TRANSFORM_DBT\notebooks\extract.py", line 7, in extract_usuarios
#     return pd.read_sql(query, engine)
#            ~~~~~~~~~~~^^^^^^^^^^^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\pandas\io\sql.py", line 704, in read_sql
#     with pandasSQL_builder(con) as pandas_sql:
#          ~~~~~~~~~~~~~~~~~^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\pandas\io\sql.py", line 906, in pandasSQL_builder
#     return SQLDatabase(con, schema, need_transaction)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\pandas\io\sql.py", line 1636, in __init__
#     con = self.exit_stack.enter_context(con.connect())
#                                         ~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py", line 3274, in connect
#     return self._connection_cls(self)
#            ~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py", line 148, in __init__
#     Connection._handle_dbapi_exception_noconnection(
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         err, dialect, engine
#         ^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py", line 2439, in _handle_dbapi_exception_noconnection
#     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py", line 146, in __init__
#     self._dbapi_connection = engine.raw_connection()
#                              ~~~~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py", line 3298, in raw_connection
#     return self.pool.connect()
#            ~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 449, in connect
#     return _ConnectionFairy._checkout(self)
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 1264, in _checkout
#     fairy = _ConnectionRecord.checkout(pool)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 713, in checkout
#     rec = pool._do_get()
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\impl.py", line 179, in _do_get
#     with util.safe_reraise():
#          ~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\util\langhelpers.py", line 146, in __exit__
#     raise exc_value.with_traceback(exc_tb)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\impl.py", line 177, in _do_get
#     return self._create_connection()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 390, in _create_connection
#     return _ConnectionRecord(self)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 675, in __init__
#     self.__connect()
#     ~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 901, in __connect
#     with util.safe_reraise():
#          ~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\util\langhelpers.py", line 146, in __exit__
#     raise exc_value.with_traceback(exc_tb)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 897, in __connect
#     self.dbapi_connection = connection = pool._invoke_creator(self)
#                                          ~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\create.py", line 646, in connect
#     return dialect.connect(*cargs, **cparams)
#            ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\default.py", line 622, in connect
#     return self.loaded_dbapi.connect(*cargs, **cparams)
#            ~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^
# sqlalchemy.exc.InterfaceError: (pyodbc.InterfaceError) ('IM002', '[IM002] [Microsoft][ODBC Driver Manager] Data source name not found and no default driver specified (0) (SQLDriverConnect); [IM002] [Microsoft][ODBC Driver Manager] Invalid connection string attribute (0)')
# (Background on this error at: https://sqlalche.me/e/20/rvf5)
# 16:30:34.068 | INFO    | Flow run 'petite-saluki' - Finished in state Failed("Flow run encountered an exception: InterfaceError: (pyodbc.InterfaceError) ('IM002', '[IM002] [Microsoft][ODBC Driver Manager] Data source name not found and no default driver specified (0) (SQLDriverConnect); [IM002] [Microsoft][ODBC Driver Manager] Invalid connection string attribute (0)')\n(Background on this error at: https://sqlalche.me/e/20/rvf5)")
# Traceback (most recent call last):
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py", line 146, in __init__
#     self._dbapi_connection = engine.raw_connection()
#                              ~~~~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py", line 3298, in raw_connection
#     return self.pool.connect()
#            ~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 449, in connect
#     return _ConnectionFairy._checkout(self)
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 1264, in _checkout
#     fairy = _ConnectionRecord.checkout(pool)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 713, in checkout
#     rec = pool._do_get()
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\impl.py", line 179, in _do_get
#     with util.safe_reraise():
#          ~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\util\langhelpers.py", line 146, in __exit__
#     raise exc_value.with_traceback(exc_tb)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\impl.py", line 177, in _do_get
#     return self._create_connection()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 390, in _create_connection
#     return _ConnectionRecord(self)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 675, in __init__
#     self.__connect()
#     ~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 901, in __connect
#     with util.safe_reraise():
#          ~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\util\langhelpers.py", line 146, in __exit__
#     raise exc_value.with_traceback(exc_tb)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 897, in __connect
#     self.dbapi_connection = connection = pool._invoke_creator(self)
#                                          ~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\create.py", line 646, in connect
#     return dialect.connect(*cargs, **cparams)
#            ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\default.py", line 622, in connect
#     return self.loaded_dbapi.connect(*cargs, **cparams)
#            ~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^
# pyodbc.InterfaceError: ('IM002', '[IM002] [Microsoft][ODBC Driver Manager] Data source name not found and no default driver specified (0) (SQLDriverConnect); [IM002] [Microsoft][ODBC Driver Manager] Invalid connection string attribute (0)')
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\Users\luisb\Desktop\3.DEM2L7TRANSFORM_DBT\notebooks\prefect_flow.py", line 35, in <module>
#     ecommerce_flow()
#     ~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\flows.py", line 1708, in __call__
#     return run_flow(
#         flow=self,
#     ...<2 lines>...
#         return_type=return_type,
#     )
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\flow_engine.py", line 1582, in run_flow
#     ret_val = run_flow_sync(**kwargs)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\flow_engine.py", line 1427, in run_flow_sync
#     return engine.state if return_type == "state" else engine.result()
#                                                        ~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\flow_engine.py", line 363, in result
#     raise self._raised
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\flow_engine.py", line 797, in run_context
#     yield self
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\flow_engine.py", line 1425, in run_flow_sync
#     engine.call_flow_fn()
#     ~~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\flow_engine.py", line 817, in call_flow_fn
#     result = call_with_parameters(self.flow.fn, self.parameters)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\utilities\callables.py", line 210, in call_with_parameters
#     return fn(*args, **kwargs)
#   File "c:\Users\luisb\Desktop\3.DEM2L7TRANSFORM_DBT\notebooks\prefect_flow.py", line 28, in ecommerce_flow
#     raw = task_extract(engine)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\tasks.py", line 1190, in __call__
#     return run_task(
#         task=self,
#     ...<2 lines>...
#         return_type=return_type,
#     )
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\task_engine.py", line 1765, in run_task
#     return run_task_sync(**kwargs)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\task_engine.py", line 1540, in run_task_sync
#     return engine.state if return_type == "state" else engine.result()
#                                                        ~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\task_engine.py", line 499, in result
#     raise self._raised
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\task_engine.py", line 884, in run_context
#     yield self
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\task_engine.py", line 1538, in run_task_sync
#     engine.call_task_fn(txn)
#     ~~~~~~~~~~~~~~~~~~~^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\task_engine.py", line 901, in call_task_fn
#     result = call_with_parameters(self.task.fn, parameters)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\utilities\callables.py", line 210, in call_with_parameters
#     return fn(*args, **kwargs)
#   File "c:\Users\luisb\Desktop\3.DEM2L7TRANSFORM_DBT\notebooks\prefect_flow.py", line 14, in task_extract
#     return extract_data(engine)
#   File "c:\Users\luisb\Desktop\3.DEM2L7TRANSFORM_DBT\notebooks\extract.py", line 19, in extract_data
#     "usuarios": extract_usuarios(engine),
#                 ~~~~~~~~~~~~~~~~^^^^^^^^
#   File "c:\Users\luisb\Desktop\3.DEM2L7TRANSFORM_DBT\notebooks\extract.py", line 7, in extract_usuarios
#     return pd.read_sql(query, engine)
#            ~~~~~~~~~~~^^^^^^^^^^^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\pandas\io\sql.py", line 704, in read_sql
#     with pandasSQL_builder(con) as pandas_sql:
#          ~~~~~~~~~~~~~~~~~^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\pandas\io\sql.py", line 906, in pandasSQL_builder
#     return SQLDatabase(con, schema, need_transaction)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\pandas\io\sql.py", line 1636, in __init__
#     con = self.exit_stack.enter_context(con.connect())
#                                         ~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py", line 3274, in connect
#     return self._connection_cls(self)
#            ~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py", line 148, in __init__
#     Connection._handle_dbapi_exception_noconnection(
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         err, dialect, engine
#         ^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py", line 2439, in _handle_dbapi_exception_noconnection
#     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py", line 146, in __init__
#     self._dbapi_connection = engine.raw_connection()
#                              ~~~~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py", line 3298, in raw_connection
#     return self.pool.connect()
#            ~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 449, in connect
#     return _ConnectionFairy._checkout(self)
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 1264, in _checkout
#     fairy = _ConnectionRecord.checkout(pool)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 713, in checkout
#     rec = pool._do_get()
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\impl.py", line 179, in _do_get
#     with util.safe_reraise():
#          ~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\util\langhelpers.py", line 146, in __exit__
#     raise exc_value.with_traceback(exc_tb)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\impl.py", line 177, in _do_get
#     return self._create_connection()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 390, in _create_connection
#     return _ConnectionRecord(self)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 675, in __init__
#     self.__connect()
#     ~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 901, in __connect
#     with util.safe_reraise():
#          ~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\util\langhelpers.py", line 146, in __exit__
#     raise exc_value.with_traceback(exc_tb)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 897, in __connect
#     self.dbapi_connection = connection = pool._invoke_creator(self)
#                                          ~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\create.py", line 646, in connect
#     return dialect.connect(*cargs, **cparams)
#            ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\default.py", line 622, in connect
#     return self.loaded_dbapi.connect(*cargs, **cparams)
#            ~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^
# sqlalchemy.exc.InterfaceError: (pyodbc.InterfaceError) ('IM002', '[IM002] [Microsoft][ODBC Driver Manager] Data source name not found and no default driver specified (0) (SQLDriverConnect); [IM002] [Microsoft][ODBC Driver Manager] Invalid connection string attribute (0)')
# (Background on this error at: https://sqlalche.me/e/20/rvf5)
# 16:30:34.302 | WARNING | EventsWorker - Still processing items: 3 items remaining...
# 16:30:34.333 | INFO    | prefect - Stopping temporary server on http://127.0.0.1:8203

# %%
# !python prefect_flow.py
# Out:
# 16:34:48.462 | INFO    | prefect - Starting temporary server on http://127.0.0.1:8612
# See https://docs.prefect.io/v3/concepts/server#how-to-guides for more information on running a dedicated Prefect server.
# 16:34:57.219 | INFO    | Flow run 'mighty-scallop' - Beginning flow run 'mighty-scallop' for flow 'ETL_Ecommerce'
# 16:34:57.615 | ERROR   | Task run 'task_extract-a77' - Error encountered when computing cache key - result will not be persisted.
# Traceback (most recent call last):
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\cache_policies.py", line 374, in compute_key
#     return hash_objects(hashed_inputs, raise_on_failure=True)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\utilities\hashing.py", line 89, in hash_objects
#     raise HashError(msg)
# prefect.exceptions.HashError: Unable to create hash - objects could not be serialized.
#   JSON error: Unable to serialize unknown type: <class 'sqlalchemy.engine.base.Engine'>
#   Pickle error: cannot pickle '_thread.RLock' object
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\task_engine.py", line 171, in compute_transaction_key
#     key = self.task.cache_policy.compute_key(
#         task_ctx=task_run_context,
#         inputs=self.parameters or {},
#         flow_parameters=parameters or {},
#     )
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\cache_policies.py", line 214, in compute_key
#     policy_key = policy.compute_key(
#         task_ctx=task_ctx,
#     ...<2 lines>...
#         **kwargs,
#     )
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\cache_policies.py", line 384, in compute_key
#     raise ValueError(msg) from exc
# ValueError: Unable to create hash - objects could not be serialized.
#   JSON error: Unable to serialize unknown type: <class 'sqlalchemy.engine.base.Engine'>
#   Pickle error: cannot pickle '_thread.RLock' object
#
# This often occurs when task inputs contain objects that cannot be cached like locks, file handles, or other system resources.
#
# To resolve this, you can:
#   1. Exclude these arguments by defining a custom `cache_key_fn`
#   2. Disable caching by passing `cache_policy=NO_CACHE`
#
# 16:34:57.623 | ERROR   | Task run 'task_extract-a77' - Task run failed with exception: InterfaceError("(pyodbc.InterfaceError) ('IM002', '[IM002] [Microsoft][ODBC Driver Manager] Data source name not found and no default driver specified (0) (SQLDriverConnect); [IM002] [Microsoft][ODBC Driver Manager] Invalid connection string attribute (0)')")
# Traceback (most recent call last):
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py", line 146, in __init__
#     self._dbapi_connection = engine.raw_connection()
#                              ~~~~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py", line 3298, in raw_connection
#     return self.pool.connect()
#            ~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 449, in connect
#     return _ConnectionFairy._checkout(self)
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 1264, in _checkout
#     fairy = _ConnectionRecord.checkout(pool)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 713, in checkout
#     rec = pool._do_get()
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\impl.py", line 179, in _do_get
#     with util.safe_reraise():
#          ~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\util\langhelpers.py", line 146, in __exit__
#     raise exc_value.with_traceback(exc_tb)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\impl.py", line 177, in _do_get
#     return self._create_connection()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 390, in _create_connection
#     return _ConnectionRecord(self)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 675, in __init__
#     self.__connect()
#     ~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 901, in __connect
#     with util.safe_reraise():
#          ~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\util\langhelpers.py", line 146, in __exit__
#     raise exc_value.with_traceback(exc_tb)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 897, in __connect
#     self.dbapi_connection = connection = pool._invoke_creator(self)
#                                          ~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\create.py", line 646, in connect
#     return dialect.connect(*cargs, **cparams)
#            ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\default.py", line 622, in connect
#     return self.loaded_dbapi.connect(*cargs, **cparams)
#            ~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^
# pyodbc.InterfaceError: ('IM002', '[IM002] [Microsoft][ODBC Driver Manager] Data source name not found and no default driver specified (0) (SQLDriverConnect); [IM002] [Microsoft][ODBC Driver Manager] Invalid connection string attribute (0)')
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\task_engine.py", line 884, in run_context
#     yield self
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\task_engine.py", line 1538, in run_task_sync
#     engine.call_task_fn(txn)
#     ~~~~~~~~~~~~~~~~~~~^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\task_engine.py", line 901, in call_task_fn
#     result = call_with_parameters(self.task.fn, parameters)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\utilities\callables.py", line 210, in call_with_parameters
#     return fn(*args, **kwargs)
#   File "c:\Users\luisb\Desktop\3.DEM2L7TRANSFORM_DBT\notebooks\prefect_flow.py", line 14, in task_extract
#     return extract_data(engine)
#   File "c:\Users\luisb\Desktop\3.DEM2L7TRANSFORM_DBT\notebooks\extract.py", line 19, in extract_data
#     "usuarios": extract_usuarios(engine),
#                 ~~~~~~~~~~~~~~~~^^^^^^^^
#   File "c:\Users\luisb\Desktop\3.DEM2L7TRANSFORM_DBT\notebooks\extract.py", line 7, in extract_usuarios
#     return pd.read_sql(query, engine)
#            ~~~~~~~~~~~^^^^^^^^^^^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\pandas\io\sql.py", line 704, in read_sql
#     with pandasSQL_builder(con) as pandas_sql:
#          ~~~~~~~~~~~~~~~~~^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\pandas\io\sql.py", line 906, in pandasSQL_builder
#     return SQLDatabase(con, schema, need_transaction)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\pandas\io\sql.py", line 1636, in __init__
#     con = self.exit_stack.enter_context(con.connect())
#                                         ~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py", line 3274, in connect
#     return self._connection_cls(self)
#            ~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py", line 148, in __init__
#     Connection._handle_dbapi_exception_noconnection(
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         err, dialect, engine
#         ^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py", line 2439, in _handle_dbapi_exception_noconnection
#     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py", line 146, in __init__
#     self._dbapi_connection = engine.raw_connection()
#                              ~~~~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py", line 3298, in raw_connection
#     return self.pool.connect()
#            ~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 449, in connect
#     return _ConnectionFairy._checkout(self)
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 1264, in _checkout
#     fairy = _ConnectionRecord.checkout(pool)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 713, in checkout
#     rec = pool._do_get()
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\impl.py", line 179, in _do_get
#     with util.safe_reraise():
#          ~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\util\langhelpers.py", line 146, in __exit__
#     raise exc_value.with_traceback(exc_tb)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\impl.py", line 177, in _do_get
#     return self._create_connection()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 390, in _create_connection
#     return _ConnectionRecord(self)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 675, in __init__
#     self.__connect()
#     ~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 901, in __connect
#     with util.safe_reraise():
#          ~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\util\langhelpers.py", line 146, in __exit__
#     raise exc_value.with_traceback(exc_tb)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 897, in __connect
#     self.dbapi_connection = connection = pool._invoke_creator(self)
#                                          ~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\create.py", line 646, in connect
#     return dialect.connect(*cargs, **cparams)
#            ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\default.py", line 622, in connect
#     return self.loaded_dbapi.connect(*cargs, **cparams)
#            ~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^
# sqlalchemy.exc.InterfaceError: (pyodbc.InterfaceError) ('IM002', '[IM002] [Microsoft][ODBC Driver Manager] Data source name not found and no default driver specified (0) (SQLDriverConnect); [IM002] [Microsoft][ODBC Driver Manager] Invalid connection string attribute (0)')
# (Background on this error at: https://sqlalche.me/e/20/rvf5)
# 16:34:57.644 | ERROR   | Task run 'task_extract-a77' - Finished in state Failed("Task run encountered an exception InterfaceError: (pyodbc.InterfaceError) ('IM002', '[IM002] [Microsoft][ODBC Driver Manager] Data source name not found and no default driver specified (0) (SQLDriverConnect); [IM002] [Microsoft][ODBC Driver Manager] Invalid connection string attribute (0)')\n(Background on this error at: https://sqlalche.me/e/20/rvf5)")
# 16:34:57.644 | ERROR   | Flow run 'mighty-scallop' - Encountered exception during execution: InterfaceError("(pyodbc.InterfaceError) ('IM002', '[IM002] [Microsoft][ODBC Driver Manager] Data source name not found and no default driver specified (0) (SQLDriverConnect); [IM002] [Microsoft][ODBC Driver Manager] Invalid connection string attribute (0)')")
# Traceback (most recent call last):
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py", line 146, in __init__
#     self._dbapi_connection = engine.raw_connection()
#                              ~~~~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py", line 3298, in raw_connection
#     return self.pool.connect()
#            ~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 449, in connect
#     return _ConnectionFairy._checkout(self)
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 1264, in _checkout
#     fairy = _ConnectionRecord.checkout(pool)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 713, in checkout
#     rec = pool._do_get()
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\impl.py", line 179, in _do_get
#     with util.safe_reraise():
#          ~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\util\langhelpers.py", line 146, in __exit__
#     raise exc_value.with_traceback(exc_tb)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\impl.py", line 177, in _do_get
#     return self._create_connection()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 390, in _create_connection
#     return _ConnectionRecord(self)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 675, in __init__
#     self.__connect()
#     ~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 901, in __connect
#     with util.safe_reraise():
#          ~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\util\langhelpers.py", line 146, in __exit__
#     raise exc_value.with_traceback(exc_tb)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 897, in __connect
#     self.dbapi_connection = connection = pool._invoke_creator(self)
#                                          ~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\create.py", line 646, in connect
#     return dialect.connect(*cargs, **cparams)
#            ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\default.py", line 622, in connect
#     return self.loaded_dbapi.connect(*cargs, **cparams)
#            ~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^
# pyodbc.InterfaceError: ('IM002', '[IM002] [Microsoft][ODBC Driver Manager] Data source name not found and no default driver specified (0) (SQLDriverConnect); [IM002] [Microsoft][ODBC Driver Manager] Invalid connection string attribute (0)')
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\flow_engine.py", line 797, in run_context
#     yield self
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\flow_engine.py", line 1425, in run_flow_sync
#     engine.call_flow_fn()
#     ~~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\flow_engine.py", line 817, in call_flow_fn
#     result = call_with_parameters(self.flow.fn, self.parameters)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\utilities\callables.py", line 210, in call_with_parameters
#     return fn(*args, **kwargs)
#   File "c:\Users\luisb\Desktop\3.DEM2L7TRANSFORM_DBT\notebooks\prefect_flow.py", line 28, in ecommerce_flow
#     raw = task_extract(engine)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\tasks.py", line 1190, in __call__
#     return run_task(
#         task=self,
#     ...<2 lines>...
#         return_type=return_type,
#     )
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\task_engine.py", line 1765, in run_task
#     return run_task_sync(**kwargs)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\task_engine.py", line 1540, in run_task_sync
#     return engine.state if return_type == "state" else engine.result()
#                                                        ~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\task_engine.py", line 499, in result
#     raise self._raised
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\task_engine.py", line 884, in run_context
#     yield self
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\task_engine.py", line 1538, in run_task_sync
#     engine.call_task_fn(txn)
#     ~~~~~~~~~~~~~~~~~~~^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\task_engine.py", line 901, in call_task_fn
#     result = call_with_parameters(self.task.fn, parameters)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\utilities\callables.py", line 210, in call_with_parameters
#     return fn(*args, **kwargs)
#   File "c:\Users\luisb\Desktop\3.DEM2L7TRANSFORM_DBT\notebooks\prefect_flow.py", line 14, in task_extract
#     return extract_data(engine)
#   File "c:\Users\luisb\Desktop\3.DEM2L7TRANSFORM_DBT\notebooks\extract.py", line 19, in extract_data
#     "usuarios": extract_usuarios(engine),
#                 ~~~~~~~~~~~~~~~~^^^^^^^^
#   File "c:\Users\luisb\Desktop\3.DEM2L7TRANSFORM_DBT\notebooks\extract.py", line 7, in extract_usuarios
#     return pd.read_sql(query, engine)
#            ~~~~~~~~~~~^^^^^^^^^^^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\pandas\io\sql.py", line 704, in read_sql
#     with pandasSQL_builder(con) as pandas_sql:
#          ~~~~~~~~~~~~~~~~~^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\pandas\io\sql.py", line 906, in pandasSQL_builder
#     return SQLDatabase(con, schema, need_transaction)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\pandas\io\sql.py", line 1636, in __init__
#     con = self.exit_stack.enter_context(con.connect())
#                                         ~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py", line 3274, in connect
#     return self._connection_cls(self)
#            ~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py", line 148, in __init__
#     Connection._handle_dbapi_exception_noconnection(
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         err, dialect, engine
#         ^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py", line 2439, in _handle_dbapi_exception_noconnection
#     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py", line 146, in __init__
#     self._dbapi_connection = engine.raw_connection()
#                              ~~~~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py", line 3298, in raw_connection
#     return self.pool.connect()
#            ~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 449, in connect
#     return _ConnectionFairy._checkout(self)
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 1264, in _checkout
#     fairy = _ConnectionRecord.checkout(pool)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 713, in checkout
#     rec = pool._do_get()
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\impl.py", line 179, in _do_get
#     with util.safe_reraise():
#          ~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\util\langhelpers.py", line 146, in __exit__
#     raise exc_value.with_traceback(exc_tb)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\impl.py", line 177, in _do_get
#     return self._create_connection()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 390, in _create_connection
#     return _ConnectionRecord(self)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 675, in __init__
#     self.__connect()
#     ~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 901, in __connect
#     with util.safe_reraise():
#          ~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\util\langhelpers.py", line 146, in __exit__
#     raise exc_value.with_traceback(exc_tb)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 897, in __connect
#     self.dbapi_connection = connection = pool._invoke_creator(self)
#                                          ~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\create.py", line 646, in connect
#     return dialect.connect(*cargs, **cparams)
#            ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\default.py", line 622, in connect
#     return self.loaded_dbapi.connect(*cargs, **cparams)
#            ~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^
# sqlalchemy.exc.InterfaceError: (pyodbc.InterfaceError) ('IM002', '[IM002] [Microsoft][ODBC Driver Manager] Data source name not found and no default driver specified (0) (SQLDriverConnect); [IM002] [Microsoft][ODBC Driver Manager] Invalid connection string attribute (0)')
# (Background on this error at: https://sqlalche.me/e/20/rvf5)
# 16:34:57.675 | INFO    | Flow run 'mighty-scallop' - Finished in state Failed("Flow run encountered an exception: InterfaceError: (pyodbc.InterfaceError) ('IM002', '[IM002] [Microsoft][ODBC Driver Manager] Data source name not found and no default driver specified (0) (SQLDriverConnect); [IM002] [Microsoft][ODBC Driver Manager] Invalid connection string attribute (0)')\n(Background on this error at: https://sqlalche.me/e/20/rvf5)")
# Traceback (most recent call last):
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py", line 146, in __init__
#     self._dbapi_connection = engine.raw_connection()
#                              ~~~~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py", line 3298, in raw_connection
#     return self.pool.connect()
#            ~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 449, in connect
#     return _ConnectionFairy._checkout(self)
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 1264, in _checkout
#     fairy = _ConnectionRecord.checkout(pool)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 713, in checkout
#     rec = pool._do_get()
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\impl.py", line 179, in _do_get
#     with util.safe_reraise():
#          ~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\util\langhelpers.py", line 146, in __exit__
#     raise exc_value.with_traceback(exc_tb)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\impl.py", line 177, in _do_get
#     return self._create_connection()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 390, in _create_connection
#     return _ConnectionRecord(self)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 675, in __init__
#     self.__connect()
#     ~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 901, in __connect
#     with util.safe_reraise():
#          ~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\util\langhelpers.py", line 146, in __exit__
#     raise exc_value.with_traceback(exc_tb)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 897, in __connect
#     self.dbapi_connection = connection = pool._invoke_creator(self)
#                                          ~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\create.py", line 646, in connect
#     return dialect.connect(*cargs, **cparams)
#            ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\default.py", line 622, in connect
#     return self.loaded_dbapi.connect(*cargs, **cparams)
#            ~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^
# pyodbc.InterfaceError: ('IM002', '[IM002] [Microsoft][ODBC Driver Manager] Data source name not found and no default driver specified (0) (SQLDriverConnect); [IM002] [Microsoft][ODBC Driver Manager] Invalid connection string attribute (0)')
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\Users\luisb\Desktop\3.DEM2L7TRANSFORM_DBT\notebooks\prefect_flow.py", line 35, in <module>
#     ecommerce_flow()
#     ~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\flows.py", line 1708, in __call__
#     return run_flow(
#         flow=self,
#     ...<2 lines>...
#         return_type=return_type,
#     )
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\flow_engine.py", line 1582, in run_flow
#     ret_val = run_flow_sync(**kwargs)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\flow_engine.py", line 1427, in run_flow_sync
#     return engine.state if return_type == "state" else engine.result()
#                                                        ~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\flow_engine.py", line 363, in result
#     raise self._raised
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\flow_engine.py", line 797, in run_context
#     yield self
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\flow_engine.py", line 1425, in run_flow_sync
#     engine.call_flow_fn()
#     ~~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\flow_engine.py", line 817, in call_flow_fn
#     result = call_with_parameters(self.flow.fn, self.parameters)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\utilities\callables.py", line 210, in call_with_parameters
#     return fn(*args, **kwargs)
#   File "c:\Users\luisb\Desktop\3.DEM2L7TRANSFORM_DBT\notebooks\prefect_flow.py", line 28, in ecommerce_flow
#     raw = task_extract(engine)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\tasks.py", line 1190, in __call__
#     return run_task(
#         task=self,
#     ...<2 lines>...
#         return_type=return_type,
#     )
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\task_engine.py", line 1765, in run_task
#     return run_task_sync(**kwargs)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\task_engine.py", line 1540, in run_task_sync
#     return engine.state if return_type == "state" else engine.result()
#                                                        ~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\task_engine.py", line 499, in result
#     raise self._raised
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\task_engine.py", line 884, in run_context
#     yield self
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\task_engine.py", line 1538, in run_task_sync
#     engine.call_task_fn(txn)
#     ~~~~~~~~~~~~~~~~~~~^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\task_engine.py", line 901, in call_task_fn
#     result = call_with_parameters(self.task.fn, parameters)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\utilities\callables.py", line 210, in call_with_parameters
#     return fn(*args, **kwargs)
#   File "c:\Users\luisb\Desktop\3.DEM2L7TRANSFORM_DBT\notebooks\prefect_flow.py", line 14, in task_extract
#     return extract_data(engine)
#   File "c:\Users\luisb\Desktop\3.DEM2L7TRANSFORM_DBT\notebooks\extract.py", line 19, in extract_data
#     "usuarios": extract_usuarios(engine),
#                 ~~~~~~~~~~~~~~~~^^^^^^^^
#   File "c:\Users\luisb\Desktop\3.DEM2L7TRANSFORM_DBT\notebooks\extract.py", line 7, in extract_usuarios
#     return pd.read_sql(query, engine)
#            ~~~~~~~~~~~^^^^^^^^^^^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\pandas\io\sql.py", line 704, in read_sql
#     with pandasSQL_builder(con) as pandas_sql:
#          ~~~~~~~~~~~~~~~~~^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\pandas\io\sql.py", line 906, in pandasSQL_builder
#     return SQLDatabase(con, schema, need_transaction)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\pandas\io\sql.py", line 1636, in __init__
#     con = self.exit_stack.enter_context(con.connect())
#                                         ~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py", line 3274, in connect
#     return self._connection_cls(self)
#            ~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py", line 148, in __init__
#     Connection._handle_dbapi_exception_noconnection(
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         err, dialect, engine
#         ^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py", line 2439, in _handle_dbapi_exception_noconnection
#     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py", line 146, in __init__
#     self._dbapi_connection = engine.raw_connection()
#                              ~~~~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py", line 3298, in raw_connection
#     return self.pool.connect()
#            ~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 449, in connect
#     return _ConnectionFairy._checkout(self)
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 1264, in _checkout
#     fairy = _ConnectionRecord.checkout(pool)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 713, in checkout
#     rec = pool._do_get()
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\impl.py", line 179, in _do_get
#     with util.safe_reraise():
#          ~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\util\langhelpers.py", line 146, in __exit__
#     raise exc_value.with_traceback(exc_tb)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\impl.py", line 177, in _do_get
#     return self._create_connection()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 390, in _create_connection
#     return _ConnectionRecord(self)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 675, in __init__
#     self.__connect()
#     ~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 901, in __connect
#     with util.safe_reraise():
#          ~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\util\langhelpers.py", line 146, in __exit__
#     raise exc_value.with_traceback(exc_tb)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 897, in __connect
#     self.dbapi_connection = connection = pool._invoke_creator(self)
#                                          ~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\create.py", line 646, in connect
#     return dialect.connect(*cargs, **cparams)
#            ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\default.py", line 622, in connect
#     return self.loaded_dbapi.connect(*cargs, **cparams)
#            ~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^
# sqlalchemy.exc.InterfaceError: (pyodbc.InterfaceError) ('IM002', '[IM002] [Microsoft][ODBC Driver Manager] Data source name not found and no default driver specified (0) (SQLDriverConnect); [IM002] [Microsoft][ODBC Driver Manager] Invalid connection string attribute (0)')
# (Background on this error at: https://sqlalche.me/e/20/rvf5)
# 16:34:57.900 | WARNING | EventsWorker - Still processing items: 3 items remaining...
# 16:34:57.929 | INFO    | prefect - Stopping temporary server on http://127.0.0.1:8612

# %%
# !python prefect_flow.py
# Out:
# 16:37:11.292 | INFO    | prefect - Starting temporary server on http://127.0.0.1:8491
# See https://docs.prefect.io/v3/concepts/server#how-to-guides for more information on running a dedicated Prefect server.
# 16:37:20.557 | INFO    | Flow run 'imported-skylark' - Beginning flow run 'imported-skylark' for flow 'ETL_Ecommerce'
# 16:37:20.951 | ERROR   | Task run 'task_extract-739' - Error encountered when computing cache key - result will not be persisted.
# Traceback (most recent call last):
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\cache_policies.py", line 374, in compute_key
#     return hash_objects(hashed_inputs, raise_on_failure=True)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\utilities\hashing.py", line 89, in hash_objects
#     raise HashError(msg)
# prefect.exceptions.HashError: Unable to create hash - objects could not be serialized.
#   JSON error: Unable to serialize unknown type: <class 'sqlalchemy.engine.base.Engine'>
#   Pickle error: cannot pickle '_thread.RLock' object
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\task_engine.py", line 171, in compute_transaction_key
#     key = self.task.cache_policy.compute_key(
#         task_ctx=task_run_context,
#         inputs=self.parameters or {},
#         flow_parameters=parameters or {},
#     )
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\cache_policies.py", line 214, in compute_key
#     policy_key = policy.compute_key(
#         task_ctx=task_ctx,
#     ...<2 lines>...
#         **kwargs,
#     )
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\cache_policies.py", line 384, in compute_key
#     raise ValueError(msg) from exc
# ValueError: Unable to create hash - objects could not be serialized.
#   JSON error: Unable to serialize unknown type: <class 'sqlalchemy.engine.base.Engine'>
#   Pickle error: cannot pickle '_thread.RLock' object
#
# This often occurs when task inputs contain objects that cannot be cached like locks, file handles, or other system resources.
#
# To resolve this, you can:
#   1. Exclude these arguments by defining a custom `cache_key_fn`
#   2. Disable caching by passing `cache_policy=NO_CACHE`
#
# 16:37:20.959 | ERROR   | Task run 'task_extract-739' - Task run failed with exception: InterfaceError("(pyodbc.InterfaceError) ('IM002', '[IM002] [Microsoft][ODBC Driver Manager] Data source name not found and no default driver specified (0) (SQLDriverConnect); [IM002] [Microsoft][ODBC Driver Manager] Invalid connection string attribute (0)')")
# Traceback (most recent call last):
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py", line 146, in __init__
#     self._dbapi_connection = engine.raw_connection()
#                              ~~~~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py", line 3298, in raw_connection
#     return self.pool.connect()
#            ~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 449, in connect
#     return _ConnectionFairy._checkout(self)
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 1264, in _checkout
#     fairy = _ConnectionRecord.checkout(pool)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 713, in checkout
#     rec = pool._do_get()
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\impl.py", line 179, in _do_get
#     with util.safe_reraise():
#          ~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\util\langhelpers.py", line 146, in __exit__
#     raise exc_value.with_traceback(exc_tb)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\impl.py", line 177, in _do_get
#     return self._create_connection()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 390, in _create_connection
#     return _ConnectionRecord(self)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 675, in __init__
#     self.__connect()
#     ~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 901, in __connect
#     with util.safe_reraise():
#          ~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\util\langhelpers.py", line 146, in __exit__
#     raise exc_value.with_traceback(exc_tb)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 897, in __connect
#     self.dbapi_connection = connection = pool._invoke_creator(self)
#                                          ~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\create.py", line 646, in connect
#     return dialect.connect(*cargs, **cparams)
#            ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\default.py", line 622, in connect
#     return self.loaded_dbapi.connect(*cargs, **cparams)
#            ~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^
# pyodbc.InterfaceError: ('IM002', '[IM002] [Microsoft][ODBC Driver Manager] Data source name not found and no default driver specified (0) (SQLDriverConnect); [IM002] [Microsoft][ODBC Driver Manager] Invalid connection string attribute (0)')
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\task_engine.py", line 884, in run_context
#     yield self
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\task_engine.py", line 1538, in run_task_sync
#     engine.call_task_fn(txn)
#     ~~~~~~~~~~~~~~~~~~~^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\task_engine.py", line 901, in call_task_fn
#     result = call_with_parameters(self.task.fn, parameters)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\utilities\callables.py", line 210, in call_with_parameters
#     return fn(*args, **kwargs)
#   File "c:\Users\luisb\Desktop\3.DEM2L7TRANSFORM_DBT\notebooks\prefect_flow.py", line 14, in task_extract
#     return extract_data(engine)
#   File "c:\Users\luisb\Desktop\3.DEM2L7TRANSFORM_DBT\notebooks\extract.py", line 19, in extract_data
#     "usuarios": extract_usuarios(engine),
#                 ~~~~~~~~~~~~~~~~^^^^^^^^
#   File "c:\Users\luisb\Desktop\3.DEM2L7TRANSFORM_DBT\notebooks\extract.py", line 7, in extract_usuarios
#     return pd.read_sql(query, engine)
#            ~~~~~~~~~~~^^^^^^^^^^^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\pandas\io\sql.py", line 704, in read_sql
#     with pandasSQL_builder(con) as pandas_sql:
#          ~~~~~~~~~~~~~~~~~^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\pandas\io\sql.py", line 906, in pandasSQL_builder
#     return SQLDatabase(con, schema, need_transaction)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\pandas\io\sql.py", line 1636, in __init__
#     con = self.exit_stack.enter_context(con.connect())
#                                         ~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py", line 3274, in connect
#     return self._connection_cls(self)
#            ~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py", line 148, in __init__
#     Connection._handle_dbapi_exception_noconnection(
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         err, dialect, engine
#         ^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py", line 2439, in _handle_dbapi_exception_noconnection
#     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py", line 146, in __init__
#     self._dbapi_connection = engine.raw_connection()
#                              ~~~~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py", line 3298, in raw_connection
#     return self.pool.connect()
#            ~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 449, in connect
#     return _ConnectionFairy._checkout(self)
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 1264, in _checkout
#     fairy = _ConnectionRecord.checkout(pool)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 713, in checkout
#     rec = pool._do_get()
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\impl.py", line 179, in _do_get
#     with util.safe_reraise():
#          ~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\util\langhelpers.py", line 146, in __exit__
#     raise exc_value.with_traceback(exc_tb)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\impl.py", line 177, in _do_get
#     return self._create_connection()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 390, in _create_connection
#     return _ConnectionRecord(self)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 675, in __init__
#     self.__connect()
#     ~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 901, in __connect
#     with util.safe_reraise():
#          ~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\util\langhelpers.py", line 146, in __exit__
#     raise exc_value.with_traceback(exc_tb)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 897, in __connect
#     self.dbapi_connection = connection = pool._invoke_creator(self)
#                                          ~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\create.py", line 646, in connect
#     return dialect.connect(*cargs, **cparams)
#            ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\default.py", line 622, in connect
#     return self.loaded_dbapi.connect(*cargs, **cparams)
#            ~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^
# sqlalchemy.exc.InterfaceError: (pyodbc.InterfaceError) ('IM002', '[IM002] [Microsoft][ODBC Driver Manager] Data source name not found and no default driver specified (0) (SQLDriverConnect); [IM002] [Microsoft][ODBC Driver Manager] Invalid connection string attribute (0)')
# (Background on this error at: https://sqlalche.me/e/20/rvf5)
# 16:37:20.979 | ERROR   | Task run 'task_extract-739' - Finished in state Failed("Task run encountered an exception InterfaceError: (pyodbc.InterfaceError) ('IM002', '[IM002] [Microsoft][ODBC Driver Manager] Data source name not found and no default driver specified (0) (SQLDriverConnect); [IM002] [Microsoft][ODBC Driver Manager] Invalid connection string attribute (0)')\n(Background on this error at: https://sqlalche.me/e/20/rvf5)")
# 16:37:20.980 | ERROR   | Flow run 'imported-skylark' - Encountered exception during execution: InterfaceError("(pyodbc.InterfaceError) ('IM002', '[IM002] [Microsoft][ODBC Driver Manager] Data source name not found and no default driver specified (0) (SQLDriverConnect); [IM002] [Microsoft][ODBC Driver Manager] Invalid connection string attribute (0)')")
# Traceback (most recent call last):
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py", line 146, in __init__
#     self._dbapi_connection = engine.raw_connection()
#                              ~~~~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py", line 3298, in raw_connection
#     return self.pool.connect()
#            ~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 449, in connect
#     return _ConnectionFairy._checkout(self)
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 1264, in _checkout
#     fairy = _ConnectionRecord.checkout(pool)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 713, in checkout
#     rec = pool._do_get()
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\impl.py", line 179, in _do_get
#     with util.safe_reraise():
#          ~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\util\langhelpers.py", line 146, in __exit__
#     raise exc_value.with_traceback(exc_tb)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\impl.py", line 177, in _do_get
#     return self._create_connection()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 390, in _create_connection
#     return _ConnectionRecord(self)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 675, in __init__
#     self.__connect()
#     ~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 901, in __connect
#     with util.safe_reraise():
#          ~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\util\langhelpers.py", line 146, in __exit__
#     raise exc_value.with_traceback(exc_tb)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 897, in __connect
#     self.dbapi_connection = connection = pool._invoke_creator(self)
#                                          ~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\create.py", line 646, in connect
#     return dialect.connect(*cargs, **cparams)
#            ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\default.py", line 622, in connect
#     return self.loaded_dbapi.connect(*cargs, **cparams)
#            ~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^
# pyodbc.InterfaceError: ('IM002', '[IM002] [Microsoft][ODBC Driver Manager] Data source name not found and no default driver specified (0) (SQLDriverConnect); [IM002] [Microsoft][ODBC Driver Manager] Invalid connection string attribute (0)')
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\flow_engine.py", line 797, in run_context
#     yield self
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\flow_engine.py", line 1425, in run_flow_sync
#     engine.call_flow_fn()
#     ~~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\flow_engine.py", line 817, in call_flow_fn
#     result = call_with_parameters(self.flow.fn, self.parameters)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\utilities\callables.py", line 210, in call_with_parameters
#     return fn(*args, **kwargs)
#   File "c:\Users\luisb\Desktop\3.DEM2L7TRANSFORM_DBT\notebooks\prefect_flow.py", line 28, in ecommerce_flow
#     raw = task_extract(engine)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\tasks.py", line 1190, in __call__
#     return run_task(
#         task=self,
#     ...<2 lines>...
#         return_type=return_type,
#     )
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\task_engine.py", line 1765, in run_task
#     return run_task_sync(**kwargs)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\task_engine.py", line 1540, in run_task_sync
#     return engine.state if return_type == "state" else engine.result()
#                                                        ~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\task_engine.py", line 499, in result
#     raise self._raised
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\task_engine.py", line 884, in run_context
#     yield self
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\task_engine.py", line 1538, in run_task_sync
#     engine.call_task_fn(txn)
#     ~~~~~~~~~~~~~~~~~~~^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\task_engine.py", line 901, in call_task_fn
#     result = call_with_parameters(self.task.fn, parameters)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\utilities\callables.py", line 210, in call_with_parameters
#     return fn(*args, **kwargs)
#   File "c:\Users\luisb\Desktop\3.DEM2L7TRANSFORM_DBT\notebooks\prefect_flow.py", line 14, in task_extract
#     return extract_data(engine)
#   File "c:\Users\luisb\Desktop\3.DEM2L7TRANSFORM_DBT\notebooks\extract.py", line 19, in extract_data
#     "usuarios": extract_usuarios(engine),
#                 ~~~~~~~~~~~~~~~~^^^^^^^^
#   File "c:\Users\luisb\Desktop\3.DEM2L7TRANSFORM_DBT\notebooks\extract.py", line 7, in extract_usuarios
#     return pd.read_sql(query, engine)
#            ~~~~~~~~~~~^^^^^^^^^^^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\pandas\io\sql.py", line 704, in read_sql
#     with pandasSQL_builder(con) as pandas_sql:
#          ~~~~~~~~~~~~~~~~~^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\pandas\io\sql.py", line 906, in pandasSQL_builder
#     return SQLDatabase(con, schema, need_transaction)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\pandas\io\sql.py", line 1636, in __init__
#     con = self.exit_stack.enter_context(con.connect())
#                                         ~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py", line 3274, in connect
#     return self._connection_cls(self)
#            ~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py", line 148, in __init__
#     Connection._handle_dbapi_exception_noconnection(
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         err, dialect, engine
#         ^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py", line 2439, in _handle_dbapi_exception_noconnection
#     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py", line 146, in __init__
#     self._dbapi_connection = engine.raw_connection()
#                              ~~~~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py", line 3298, in raw_connection
#     return self.pool.connect()
#            ~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 449, in connect
#     return _ConnectionFairy._checkout(self)
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 1264, in _checkout
#     fairy = _ConnectionRecord.checkout(pool)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 713, in checkout
#     rec = pool._do_get()
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\impl.py", line 179, in _do_get
#     with util.safe_reraise():
#          ~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\util\langhelpers.py", line 146, in __exit__
#     raise exc_value.with_traceback(exc_tb)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\impl.py", line 177, in _do_get
#     return self._create_connection()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 390, in _create_connection
#     return _ConnectionRecord(self)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 675, in __init__
#     self.__connect()
#     ~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 901, in __connect
#     with util.safe_reraise():
#          ~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\util\langhelpers.py", line 146, in __exit__
#     raise exc_value.with_traceback(exc_tb)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 897, in __connect
#     self.dbapi_connection = connection = pool._invoke_creator(self)
#                                          ~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\create.py", line 646, in connect
#     return dialect.connect(*cargs, **cparams)
#            ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\default.py", line 622, in connect
#     return self.loaded_dbapi.connect(*cargs, **cparams)
#            ~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^
# sqlalchemy.exc.InterfaceError: (pyodbc.InterfaceError) ('IM002', '[IM002] [Microsoft][ODBC Driver Manager] Data source name not found and no default driver specified (0) (SQLDriverConnect); [IM002] [Microsoft][ODBC Driver Manager] Invalid connection string attribute (0)')
# (Background on this error at: https://sqlalche.me/e/20/rvf5)
# 16:37:21.009 | INFO    | Flow run 'imported-skylark' - Finished in state Failed("Flow run encountered an exception: InterfaceError: (pyodbc.InterfaceError) ('IM002', '[IM002] [Microsoft][ODBC Driver Manager] Data source name not found and no default driver specified (0) (SQLDriverConnect); [IM002] [Microsoft][ODBC Driver Manager] Invalid connection string attribute (0)')\n(Background on this error at: https://sqlalche.me/e/20/rvf5)")
# Traceback (most recent call last):
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py", line 146, in __init__
#     self._dbapi_connection = engine.raw_connection()
#                              ~~~~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py", line 3298, in raw_connection
#     return self.pool.connect()
#            ~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 449, in connect
#     return _ConnectionFairy._checkout(self)
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 1264, in _checkout
#     fairy = _ConnectionRecord.checkout(pool)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 713, in checkout
#     rec = pool._do_get()
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\impl.py", line 179, in _do_get
#     with util.safe_reraise():
#          ~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\util\langhelpers.py", line 146, in __exit__
#     raise exc_value.with_traceback(exc_tb)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\impl.py", line 177, in _do_get
#     return self._create_connection()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 390, in _create_connection
#     return _ConnectionRecord(self)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 675, in __init__
#     self.__connect()
#     ~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 901, in __connect
#     with util.safe_reraise():
#          ~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\util\langhelpers.py", line 146, in __exit__
#     raise exc_value.with_traceback(exc_tb)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 897, in __connect
#     self.dbapi_connection = connection = pool._invoke_creator(self)
#                                          ~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\create.py", line 646, in connect
#     return dialect.connect(*cargs, **cparams)
#            ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\default.py", line 622, in connect
#     return self.loaded_dbapi.connect(*cargs, **cparams)
#            ~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^
# pyodbc.InterfaceError: ('IM002', '[IM002] [Microsoft][ODBC Driver Manager] Data source name not found and no default driver specified (0) (SQLDriverConnect); [IM002] [Microsoft][ODBC Driver Manager] Invalid connection string attribute (0)')
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\Users\luisb\Desktop\3.DEM2L7TRANSFORM_DBT\notebooks\prefect_flow.py", line 35, in <module>
#     ecommerce_flow()
#     ~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\flows.py", line 1708, in __call__
#     return run_flow(
#         flow=self,
#     ...<2 lines>...
#         return_type=return_type,
#     )
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\flow_engine.py", line 1582, in run_flow
#     ret_val = run_flow_sync(**kwargs)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\flow_engine.py", line 1427, in run_flow_sync
#     return engine.state if return_type == "state" else engine.result()
#                                                        ~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\flow_engine.py", line 363, in result
#     raise self._raised
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\flow_engine.py", line 797, in run_context
#     yield self
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\flow_engine.py", line 1425, in run_flow_sync
#     engine.call_flow_fn()
#     ~~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\flow_engine.py", line 817, in call_flow_fn
#     result = call_with_parameters(self.flow.fn, self.parameters)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\utilities\callables.py", line 210, in call_with_parameters
#     return fn(*args, **kwargs)
#   File "c:\Users\luisb\Desktop\3.DEM2L7TRANSFORM_DBT\notebooks\prefect_flow.py", line 28, in ecommerce_flow
#     raw = task_extract(engine)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\tasks.py", line 1190, in __call__
#     return run_task(
#         task=self,
#     ...<2 lines>...
#         return_type=return_type,
#     )
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\task_engine.py", line 1765, in run_task
#     return run_task_sync(**kwargs)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\task_engine.py", line 1540, in run_task_sync
#     return engine.state if return_type == "state" else engine.result()
#                                                        ~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\task_engine.py", line 499, in result
#     raise self._raised
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\task_engine.py", line 884, in run_context
#     yield self
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\task_engine.py", line 1538, in run_task_sync
#     engine.call_task_fn(txn)
#     ~~~~~~~~~~~~~~~~~~~^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\task_engine.py", line 901, in call_task_fn
#     result = call_with_parameters(self.task.fn, parameters)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\prefect\utilities\callables.py", line 210, in call_with_parameters
#     return fn(*args, **kwargs)
#   File "c:\Users\luisb\Desktop\3.DEM2L7TRANSFORM_DBT\notebooks\prefect_flow.py", line 14, in task_extract
#     return extract_data(engine)
#   File "c:\Users\luisb\Desktop\3.DEM2L7TRANSFORM_DBT\notebooks\extract.py", line 19, in extract_data
#     "usuarios": extract_usuarios(engine),
#                 ~~~~~~~~~~~~~~~~^^^^^^^^
#   File "c:\Users\luisb\Desktop\3.DEM2L7TRANSFORM_DBT\notebooks\extract.py", line 7, in extract_usuarios
#     return pd.read_sql(query, engine)
#            ~~~~~~~~~~~^^^^^^^^^^^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\pandas\io\sql.py", line 704, in read_sql
#     with pandasSQL_builder(con) as pandas_sql:
#          ~~~~~~~~~~~~~~~~~^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\pandas\io\sql.py", line 906, in pandasSQL_builder
#     return SQLDatabase(con, schema, need_transaction)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\pandas\io\sql.py", line 1636, in __init__
#     con = self.exit_stack.enter_context(con.connect())
#                                         ~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py", line 3274, in connect
#     return self._connection_cls(self)
#            ~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py", line 148, in __init__
#     Connection._handle_dbapi_exception_noconnection(
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         err, dialect, engine
#         ^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py", line 2439, in _handle_dbapi_exception_noconnection
#     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py", line 146, in __init__
#     self._dbapi_connection = engine.raw_connection()
#                              ~~~~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py", line 3298, in raw_connection
#     return self.pool.connect()
#            ~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 449, in connect
#     return _ConnectionFairy._checkout(self)
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 1264, in _checkout
#     fairy = _ConnectionRecord.checkout(pool)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 713, in checkout
#     rec = pool._do_get()
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\impl.py", line 179, in _do_get
#     with util.safe_reraise():
#          ~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\util\langhelpers.py", line 146, in __exit__
#     raise exc_value.with_traceback(exc_tb)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\impl.py", line 177, in _do_get
#     return self._create_connection()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 390, in _create_connection
#     return _ConnectionRecord(self)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 675, in __init__
#     self.__connect()
#     ~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 901, in __connect
#     with util.safe_reraise():
#          ~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\util\langhelpers.py", line 146, in __exit__
#     raise exc_value.with_traceback(exc_tb)
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 897, in __connect
#     self.dbapi_connection = connection = pool._invoke_creator(self)
#                                          ~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\create.py", line 646, in connect
#     return dialect.connect(*cargs, **cparams)
#            ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\luisb\anaconda3\Lib\site-packages\sqlalchemy\engine\default.py", line 622, in connect
#     return self.loaded_dbapi.connect(*cargs, **cparams)
#            ~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^
# sqlalchemy.exc.InterfaceError: (pyodbc.InterfaceError) ('IM002', '[IM002] [Microsoft][ODBC Driver Manager] Data source name not found and no default driver specified (0) (SQLDriverConnect); [IM002] [Microsoft][ODBC Driver Manager] Invalid connection string attribute (0)')
# (Background on this error at: https://sqlalche.me/e/20/rvf5)
# 16:37:21.229 | WARNING | EventsWorker - Still processing items: 3 items remaining...
# 16:37:21.254 | INFO    | prefect - Stopping temporary server on http://127.0.0.1:8491

# %%
conn_string = (
    "DRIVER={ODBC Driver 18 for SQL Server};"
    "SERVER=localhost\\SQLEXPRESS;"  # Ajusta si tu instancia es diferente
    "DATABASE=TuBaseDeDatos;"
    "UID=TuUsuario;"
    "PWD=TuContraseña;"
    "TrustServerCertificate=yes;"
)

# %%
import pandas as pd
from sqlalchemy import create_engine
from urllib.parse import quote_plus

driver = "ODBC Driver 17 for SQL Server"
server = "DESKTOP-JBITTNM\\SQLEXPRESS"
database = "EcommerceDB"

conn_str = f"DRIVER={{{driver}}};SERVER={server};DATABASE={database};Trusted_Connection=yes;TrustServerCertificate=yes;"
conn_str_quoted = quote_plus(conn_str)

engine = create_engine(f"mssql+pyodbc:///?odbc_connect={conn_str_quoted}")
df = pd.read_sql("SELECT TOP 5 * FROM dbo.Usuarios", engine)
print(df)
# Out:
#    UsuarioID        Nombre   Apellido       DNI  \
# 0          1       Encarna    Donaire  49877134
# 1          2  Jose Ignacio    Canales  98778810
# 2          3          José  Sebastián  80095714
# 3          4      Priscila      Vilar  94128750
# 4          5      Epifanio       Ríos  62958342
#
#                               Email     Contraseña           FechaRegistro
# 0       encarna.donaire1@correo.com  Contraseña123 2025-11-18 20:29:39.563
# 1  jose ignacio.canales2@correo.com  Contraseña123 2025-11-18 20:29:39.570
# 2        josé.sebastián3@correo.com  Contraseña123 2025-11-18 20:29:39.570
# 3        priscila.vilar4@correo.com  Contraseña123 2025-11-18 20:29:39.570
# 4         epifanio.ríos5@correo.com  Contraseña123 2025-11-18 20:29:39.570
